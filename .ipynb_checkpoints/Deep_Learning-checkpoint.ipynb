# %%
import pandas as pd

# %%
dataset = pd.read_csv('weight-height.csv')

# %%
dataset
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
X = dataset['Height']
y = dataset['Weight']

# %%
import keras
from keras.models import Sequential
# Out:
# Using TensorFlow backend.
# /Users/ankit/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/ankit/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/ankit/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# Like Linear Regression is a model (algo), same in deep learning, Sequential is also an model

# %%
model = Sequential()

# %%
from keras.layers import Dense

# %% [markdown]
# Dense works for the Neural layers, to add more layers
# activation => which kind of algorithm you want to use (linear classification or binary classification)

# %%
model.add(Dense( activation="linear", input_shape=(1, ), units=1, kernel_initializer="zeros" ,
                bias_initializer="zeros" ))
#Input shape => how many features you have in your X variable

# %% [markdown]
# Bias Initializer = Kernel Initializer

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.get_config()
# Out:
# {'name': 'sequential_1',
#  'layers': [{'class_name': 'Dense',
#    'config': {'name': 'dense_1',
#     'trainable': True,
#     'batch_input_shape': (None, 1),
#     'dtype': 'float32',
#     'units': 1,
#     'activation': 'linear',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'Zeros', 'config': {}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}}]}

# %%
model.get_weights()
# Out:
# [array([[0.]], dtype=float32), array([0.], dtype=float32)]

# %%
from keras.optimizers import Adam
model.compile(loss='mean_squared_error', optimizer=Adam())

# %%
model.fit(X,y, epochs=1000)
# Out:
# Epoch 1/1000
# 10000/10000 [==============================] - 0s 31us/step - loss: 511.4490
# Epoch 2/1000
# 10000/10000 [==============================] - 0s 25us/step - loss: 511.1754
# Epoch 3/1000
# 10000/10000 [==============================] - 0s 25us/step - loss: 510.9441
# Epoch 4/1000
# 10000/10000 [==============================] - 0s 29us/step - loss: 510.7295
# Epoch 5/1000
# 10000/10000 [==============================] - 0s 26us/step - loss: 510.5481
# Epoch 6/1000
# 10000/10000 [==============================] - 0s 26us/step - loss: 510.3826
# Epoch 7/1000
# 10000/10000 [==============================] - 0s 28us/step - loss: 510.3135
# Epoch 8/1000
# 10000/10000 [==============================] - 0s 26us/step - loss: 510.0908
# Epoch 9/1000
# 10000/10000 [==============================] - 0s 30us/step - loss: 509.8639
# Epoch 10/1000
# 10000/10000 [==============================] - 0s 26us/step - loss: 509.7192
# Epoch 11/1000
# ...

# %%
model.get_weights()
# Out:
# [array([[0.30441728]], dtype=float32), array([0.30444655], dtype=float32)]

# %%
model.get_weights()
# Out:
# [array([[3.9557786]], dtype=float32), array([-100.2294], dtype=float32)]

# %%
model.predict([73])
# Out:
# array([[188.54245]], dtype=float32)

# %%
model.save("my_weight_model.h5")
#created and saved the model

# %%
#to import and directly use the model

from keras.models import load_model
m = load_model('my_weight_model.h5')
m.predict([73])
# Out:
# array([[181.61072]], dtype=float32)
