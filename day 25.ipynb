# %%
import numpy as np

x = np.array([1,5,9,4,8, 8.5,7.6,3.6])
y = np.array([10,50,90,40,80,92,41,74])

import matplotlib.pyplot as plt

plt.scatter(x,y)

# %%
plt.plot(x,y)

# %%
x = np.array([1,5,9,4,8, 8.5])
y = np.array([10,50,90,40,80,85])

import matplotlib.pyplot as plt

plt.plot(x,y,"r")
plt.scatter(x,y, color="green", marker="o")

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
